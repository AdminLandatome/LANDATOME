# %% [markdown]
# <center>
#
# # Python E02 : Les structures conditionnelles
#
# </center>

# %% [markdown]
# *Après avoir lu la page 4 du [cours](https://landatome.pagesperso-orange.fr/00_seconde/02_python/00_Python_le_cours.pdf) faire les exercices suivants*

# %% [markdown]
# <div style = "background-color:#66ffff;">
#
# ### Exercice n°1
#
# </div>

# %% [markdown]
# On considère l'algorithme ci-dessous dans lequel $X$ et $Y$ sont des variables de type entier (int) :

# %% [markdown]
# |&emsp;algorithme&emsp;&emsp;&emsp;|
# |---|
# |Si $X$ est pair&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|
# |&emsp;alors $Y \leftarrow X/2$&emsp;&emsp;&nbsp;&nbsp;|
# |&emsp;sinon $Y \leftarrow 2X-1$ &nbsp;|
# |Fin si&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;|

# %% [markdown]
# **1. Quelle est la valeur de $Y$ pour :**

# %% [markdown]
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*

# %% [markdown]
# a. $X = 8$

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
# $Y  = ...$
#
# </div>

# %% [markdown]
# b. $X = 5$

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
# $Y  = ...$
#
# </div>

# %% [markdown]
# c. $X = 28$

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
# $Y  = ...$
#
# </div>

# %% [markdown]
# **2. Afin de vérifier les réponses, nous allons traduire notre algorithme en Python et l'inclure dans une fonction:**

# %%
def verif(X):
    if X%2 == 0:        #relire la page 1, si vous ne comprenez pas
        Y = X / 2
    else:
        Y = 2 * X - 1
    return Y

# %%
verif(15)
# Out:
# 29

# %% [markdown]
# **Utilisez cette fonction pour vérifier vos réponses**

# %% [markdown]
# <div style = "background-color:#66ffff;">
#
# ### Exercice n°2
#
# </div>

# %% [markdown]
# Un parc ouvre sa nouvelle attraction à sensations.
# La fonction ci-dessous permet de savoir si une personne de taille `t`
# peut ou non utiliser cette attraction.

# %%
def bonne_taille(t):
    if t < 132 :
        reponse = "non autorisé(e)"
    else:
        reponse = "autorisé(e)"
    return reponse

# %% [markdown]
# **1. Une personne mesure 135 cm. Peut-elle utiliser ce manège ?**

# %% [markdown]
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
#  ...
#
# </div>

# %% [markdown]
# **2. Une autre personne mesure 132 cm. Peut-elle utiliser ce manège ?**

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
#  ...
#
# </div>

# %% [markdown]
# **3. vérifiez vos réponses en utilisant la fonction bonne_taille.**

# %%
bonne_taille(150)
# Out:
# 'autorisé(e)'

# %% [markdown]
# <div style = "background-color:#66ffff;">
#
# ### Exercice n°3
#
# </div>

# %% [markdown]
# Un groupe de personnes souhaite réserver un chalet pour les sports d’hiver. Le prix de la
# location à la semaine est 800 €.
# Le forfait pour skier toute la semaine est de 220 € par personne, mais il existe un tarif « groupe » à
# 180 € par personne à partir de 5 personnes d’un même groupe.

# %% [markdown]
# **1. Compléter l’algorithme ci-dessous afin qu’il affiche en sortie le prix payé par le groupe pour
# la semaine, selon le nombre de personnes du groupe saisi en entrée :**

# %% [markdown]
# *Double-cliquez sur les "..........." pour répondre
# puis sur exécuter quand vous avez fini de répondre*

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
# |&emsp;algorithme&emsp;&emsp;&emsp;|
# |---|
# |Si $N ≥ 5$ &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|
# |&emsp;alors $P \leftarrow ...............  $|
# |&emsp;sinon $P \leftarrow ............... $ |
# |Fin si&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;|
#
# </div>

# %% [markdown]
# **2. Traduire cet algorithme en Python et l'insérer dans la fonction `prix_a_payer`.**

# %%
def prix_a_payer(N):
    ...
    ...
    ...
    ...
    return...

# %% [markdown]
# **3. Utiliser cette fonction pour déterminer le prix payé pour la semaine par un groupe de 7 personnes.**

# %% [markdown]
# **Et notez votre réponse dans le cadre jaune ci-dessous :**

# %% [markdown]
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
#  ...
#
# </div>

# %% [markdown]
# <div style = "background-color:#66ffff;">
#
# ### Exercice n°3
#
# </div>

# %% [markdown]
# La formule de Tanner permet de prévoir la taille d’une personne à l’âge adulte connaissant la taille des parents.
#
# Pour un garçon, on ajoute la demi-somme des tailles des deux parents à 6,5 ;
#
# pour une fille, on enlève 6,5 à la demi-somme des tailles des deux parents.
#
# Toutes les tailles sont exprimées en centimètres.

# %% [markdown]
#  **1. Concevoir un algorithme qui, à partir de la taille des deux parents, calcule le résultat donné par la formule de Tanner.**

# %% [markdown]
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
#  ...
#
# </div>

# %% [markdown]
# **2. Programmer cet algorithme avec le langage Python l'intégrer à la fonction `futur_taille`**

# %%
def future_taille(genre,Tpere,Tmere):
    ...
    return Tadulte

# %% [markdown]
# **3. Monsieur et Madame Tanner ont un garçon. Monsieur mesure 1m82 et Madame1m74. Prévoyez la taille de leur enfant à l'âge adulte grâce à `future_taille`.**

# %% [markdown]
# **Et notez votre réponse dans le cadre jaune ci-dessous :**

# %% [markdown]
# <div style = "background-color:#FFFF00;">
#
#  ...
#
# </div>
