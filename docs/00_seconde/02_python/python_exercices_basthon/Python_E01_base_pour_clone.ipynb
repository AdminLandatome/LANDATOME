# %% [markdown]
# <div style="background-color:#000000;color:#ffffff;padding-top:15px;padding-bottom:35px;text-align:center;font-family:Times new Roman;border-radius:10px;">
#
#  # Python E01 : Les variables
#
# </div>
#
#
# !!! warning Lecture de cours
#
# *Lisez les pages 1 et 2 du [cours](https://landatome.pagesperso-orange.fr/00_seconde/02_python/00_Python_le_cours.pdf)*
#
# !!!
#
#
# !!! note Remarque
# Il y a bien d'autres langages que python et souvent, pour être généraliste, on utilise le "langage naturel". <br>Dans ce dernier l'affectation ne se traduit pas par le symbole "=" mais par " $\leftarrow$ ".
# !!!
#
# !!! note Exemple
# affecter la valeur 3 à la variable `a` on n'écrit pas `a = 3` mais $ a \leftarrow 3 $.
#
# !!!
#
# <div style="background-color:#D6FFD8;padding-top:1px;padding-bottom:15px;text-align:left;font-style:Arial;border-radius:10px 0px 10px 0px;">
#
# ## Exercice n°1 : Python vs langage naturel
#
# </div>
#
# Dans les trois algorithmes qui suivent, c'est ce langage qui est utilisé :
#
#
# |  &emsp;&emsp;algorithme 1  |&emsp;&emsp;algorithme 2 |&emsp;&emsp; algorithme 3   |
# |--------|--------|--------|
# |$ a \leftarrow 9 $&emsp;&emsp;|$ a \leftarrow 15 $&emsp;&nbsp;&nbsp;|$ a \leftarrow 10 $&emsp;&nbsp;&nbsp;|
# |$ b \leftarrow 4 $&emsp;&emsp;|$ b \leftarrow 7 $&emsp;&emsp;|$ b \leftarrow 2 $&emsp;&emsp;|
# |$ a \leftarrow a+1 $|$ a \leftarrow b-3 $|$ a \leftarrow a^2 $&emsp;&nbsp;&nbsp;|
# |$ b \leftarrow b-2 $|$ b \leftarrow a+1 $|$ a \leftarrow b $&emsp;&emsp;|
# | | | $ b \leftarrow b \times a $|
# | | | $ a \leftarrow b  $&emsp;&emsp;|
#
#
#
# !!! question **1. Que contiennent les variables a et b, une fois l'algorithme 1 effectué ?**
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# a contient :
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:70%; text-align:center;">
#
# b contient:
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **2. Que contiennent les variables a et b, une fois l'algorithme 2 effectué ?**
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:70%; text-align:center;">
#
# a contient :
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:70%; text-align:center;">
#
# b contient:
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **3. Que contiennent les variables a et b, une fois l'algorithme 3 effectué ?**
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:70%; text-align:center;">
#
# a contient :
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:70%; text-align:center;">
#
# b contient:
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question  **4. Vérifiez vos conjectures en traduisant ces algorithmes en Python et en les executant.**
# Exemple : la dernière ligne permet d'afficher le contenu des variables `a` et `b`
#
# ```python
# a = 9
# b = 10
# print(a,b)
# ```
#
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# Pour l'algorithme n°1
#
# </div>

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# Pour l'algorithme n°2
#
# </div>

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# Pour l'algorithme n°3
#
# </div>

# %% [markdown]
# !!! question  **5. Traduire le script suivant en langage naturel :**
#
#
# ```python
# x = 0
# x = x + 2
# x = 3 * x
# x = x ** 3
# ```
#
# !!!
#
# !!! tip  Astuces
#
# - le symbole " ←  " s'obtient avec le code `$\leftarrow$`
#
# - pour passer une ligne, il faut en passer deux !
#
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
#
# </div>

# %% [markdown]
# $x \leftarrow 0$
#
# ...

# %% [markdown]
# !!! question  **6. Que contient la variable `x` à la fin du script ?**
#
#
# ```python
# x = 0
# x = x + 2
# x = 3 * x
# x = x ** 3
# ```
#
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **7. Vérifiez votre conjecture dans la console ci-dessous.**
# Pensez à ajouter :
# ```python
# print(x)
# ```
# à la fin du script.
# !!!

# %% [markdown]
# <div style="background-color:#D6FFD8;padding-top:1px;padding-bottom:15px;text-align:left;font-style:Arial;border-radius:10px 0px 10px 0px;">
#
# ## Exercice n°2 : Programme de calcul, algorithme, langage naturel, script Python
#
# </div>

# %% [markdown]
# On donne le programme de calcul suivant :

# %% [markdown]
# |  Programme de calcul &emsp;&emsp;&emsp;&emsp; |
# |--------|
# |Choisir le nombre 7&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|
# |Lui ajouter 13&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&nbsp;&nbsp;|
# |Diviser le résultat par 2&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|
# |Soustraire 3 au carré du nombre obtenu|

# %% [markdown]
# !!! question **1. Ecrire en langage naturel, en utilisant une seule variable notée N, un algorithme correspondant à ce programme de calcul.**
#
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **2. Traduire cet algorithme en script Python, dans la console ci-dessous.**
#
# !!!

# %% [markdown]
# <div style="background-color:#D6FFD8;padding-top:1px;padding-bottom:15px;text-align:left;font-style:Arial;border-radius:10px 0px 10px 0px;">
#
# ## Exercice n°3 : Automatiser un calcul à l'aide d'une fonction
#
# </div>

# %% [markdown]
# On souhaite écrire un algorithme permettant de calculer l’indice de masse corporelle (IMC) d’un individu.
#
# Cet indice se calcule avec la formule :
#
#
#
# $$IMC = \frac{masse}{taille^2}\;\;\; (en\; kg/m^2) $$
#
#
#
# !!! question **1. Quelles sont les variables que l'on doit définir ?**
#
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **2. Ecrire, en langage naturel, un algorithme permettant de calculer l'IMC d'une personne mesurant 1m80 et pesant 90kg.**
#
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **3. Traduire cet algorithme en script Python dans la console ci-dessous et le tester :**
# Pensez à terminer votre script par :
# ```python
# print(...)
# ```
# (bien sûr il faudra modifier les "...")
# !!!

# %% [markdown]
# !!! question **4. Modifier le script précédant pour calculer l'IMC d'une personne mesurant 1m75 et pesant 65kg.**
# Pensez à terminer votre script par :
# ```python
# print(...)
# ```
# (bien sûr il faudra modifier les "...")
# !!!

# %% [markdown]
# !!! warning Lecture de cours
# *On aimerait bien ne pas devoir modifier le script à chaque fois que l'on veut calculer un IMC.
# Pour cela, on va utiliserr une fonction.*
#
#
# *Lire la page 3 du [cours](https://landatome.pagesperso-orange.fr/00_seconde/02_python/00_Python_le_cours.pdf).*
#
# !!!
#
# !!! question **5. Transformer votre script en fonction dans la console ci-dessous :**
# cette fois, plus besoin du  `print`.
#
#
#
#
# !!!

# %% [markdown]
# <div style="background-color:#D6FFD8;padding-top:1px;padding-bottom:15px;text-align:left;font-style:Arial;border-radius:10px 0px 10px 0px;">
#
#   ## Exercice n°4 : Comprendre et utiliser les fonctions
#
# </div>

# %% [markdown]
# !!! question **1. On donne la fonction ("informatique") suivante :**
# ``` python
# def f(x):
#     image_de_x = 3 * x + 1
#     return image_de_x
# ```
# !!!
# !!! question **a) Donner les valeurs de f(-2) et f(4) puis de f(x):**
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
# </div>

# %% [markdown]
# f(-2) = ...
#
# f(4) = ...
#
# f(x) = ...

# %% [markdown]
# !!! question **b) Quel type de fonction ("mathématique") reconnaît-on ici ?**
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **2. On donne la fonction $g$ définie pour tout réel $x$ par $g(x)=-5x+2$. Ecrivez une fonction `g` en Python prenant comme argument `x` et renvoyant l'image de $x$ par la fonction $g$.**
# !!!

# %% [markdown]
# <div style="background-color:#D6FFD8;padding-top:1px;padding-bottom:15px;text-align:left;font-style:Arial;border-radius:10px 0px 10px 0px;">
#
# ## Exercice n°5 : s'entrainer sur les fonctions
#
# </div>
# On donne une formule qui permet de calculer la vitesse de nage $v$ d' un poisson  (en $cm.s^{-1}$)en fonction de sa longueur $L$ (exprimée en $cm$) et de la fréquence $f$ des battements de sa queue par seconde :
#
# $$v\;=\;\frac{1}{4}L(3f-4)$$

# %% [markdown]
# !!! question **1. Calculer la vitesse de nage d'un poisson de 16 cm qui avance avec 15 battements de queue par seconde**
# !!!

# %% [markdown]
# <div style="background-color:#ffff00;margin-left:10%;margin-right:50%; text-align:center;">
#
# *Double-cliquez sur les "..." pour répondre
# puis sur exécuter quand vous avez fini de répondre*
#
# </div>

# %% [markdown]
# ...

# %% [markdown]
# !!! question **2. Ecrire en Python, une fonction permettant de calculer la vitesse de nage du poisson en fonction de sa longueur et de son nombre de battements de queue par seconde.**
# !!!

# %% [markdown]
# !!! tip *Pour tester : un poisson de 5 cm qui effectue 3 battements de queue par seconde avance à une vitesse de $6.25\;cm.s^{-1}$*
# !!!
