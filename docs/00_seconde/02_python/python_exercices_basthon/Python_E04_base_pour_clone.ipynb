# %% [markdown]
# <center>
#
# # Python E04 : Les boucles non bornées
#
# </center>

# %% [markdown]
# *Après avoir lu le paragraphe V.2 du [cours](https://landatome.pagesperso-orange.fr/00_seconde/02_python/00_Python_le_cours.pdf) (page 5 et 6), faire les exercices.*

# %% [markdown]
# <div style="background-color:#66FFFF;">
#
# ### Exercice n°1 : Découverte des boucles non bornées
#
# </div>

# %% [markdown]
# On donne l’algorithme ci-dessous.
# On suppose $k = 2$ au début de l’algorithme.

# %% [markdown]
# |algorithme&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|
# |---|
# |Tant que $k<5$ faire|
# |$k \leftarrow k+1$ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|
# |Fin tant que &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|

# %% [markdown]
# Au début de la boucle, nous avons donc $k=2$ et $le\; test\;\; k<5$ renvoie $Vrai$.

# %% [markdown]
# **1) Après un premier passage dans la boucle.**

# %% [markdown]
# **1.a) On a :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $k=...$
#
# </div>

# %% [markdown]
# **1.b) et $le\;test\;\;k<5$ renvoie :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $...$
#
# </div>

# %% [markdown]
# **2) Après un deuxième passage dans la boucle.**

# %% [markdown]
# **2.a) On a :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $k=...$
#
# </div>

# %% [markdown]
# **2.b) et $le\;test\;\;k<5$ renvoie :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $...$
#
# </div>

# %% [markdown]
# **3) Après un troisième passage dans la boucle.**

# %% [markdown]
# **3.a) On a :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $k=...$
#
# </div>

# %% [markdown]
# **3.b) et $le\;test\;\;k<5$ renvoie :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $...$
#
# </div>

# %% [markdown]
# **4) A la fin de la boucle, on a :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $k=...$
#
# </div>

# %% [markdown]
# **5) On donne le script Python suivant:**

# %%
n = 245
while n >= 0:
    n = n - 1

# %% [markdown]
# **Une fois le script exécuté, on a :**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $n=...$
#
# </div>

# %% [markdown]
# <div style="background-color:#66FFFF;">
#
# ### Exercice n°2 : Utilisation des boucles non bornées
#
# </div>

# %% [markdown]
# Une espèce protégée d’oiseaux niche sur une île. On a constaté que sa population diminue de 10% chaque année. Une association tente de limiter cette diminution en introduisant sur l’île 100 oiseaux chaque année. En 2018, on recense 1 600 oiseaux.

# %% [markdown]
# **1) Montrer que l’effectif de la population en 2019 sera de 1 540 oiseaux.**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $ ...$
#
# </div>

# %% [markdown]
# **2) Dans l’algorithme ci-dessous la variable  $A$ contient, en fin d’algorithme, l’année au cours de laquelle la population passera sous la barre des 1 100 oiseaux.**

# %% [markdown]
# |Algorithme|
# |-----------|
# |$P\;\leftarrow\;1600$&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|
# |$A\;\leftarrow\;2018$&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|
# |Tant que $...$ faire|
# |&nbsp;&nbsp;&nbsp;$P\;\leftarrow\;...$|
# |&nbsp;&nbsp;&nbsp;$T\; \leftarrow \; ... $|
# |Fin tant que&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;|

# %% [markdown]
# **Complèter les trois lignes nécessaires ci-dessous.**

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# Tant que $...$ faire
#
# </div>

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $P\;\leftarrow\;...$
#
# </div>

# %% [markdown]
# <div style="background-color:#ffff00;">
#
# $A\;\leftarrow\;...$
#
# </div>

# %% [markdown]
# **3) Ecrire un script Python qui correspond à cet algorithme afin de répondre à la question posée, à savoir,à partir de quelle année la population d’oiseaux passera sous la barre des 1 100.**

# %% [markdown]
# <div style="background-color:#66FFFF;">
#
# ### Exercice n°3
#
# </div>

# %% [markdown]
# **Un nénuphar d’aire 5 cm² double de surface toutes les heures. Compléter le script Python ci-dessous pour savoir quand son aire dépassera 10 m².**

# %%
a = 5
h = 0
while .... :
    a = ...
    h = h + 1
print(...)
